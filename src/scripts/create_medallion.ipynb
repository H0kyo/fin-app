# %%
dbutils.widgets.text("catalog", "dev")

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS IDENTIFIER(:catalog || '.silver') MANAGED LOCATION 'abfss://dev@ohrycfinapp.dfs.core.windows.net/silver';
CREATE SCHEMA IF NOT EXISTS IDENTIFIER(:catalog || '.gold') MANAGED LOCATION 'abfss://dev@ohrycfinapp.dfs.core.windows.net/gold';
